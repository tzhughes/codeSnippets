# %%
library(ggplot2)


# plot the mtcars dataset with ggplot
ggplot(mtcars, aes(x = wt, y = mpg)) +
    geom_point(size = 21)

# plot the mtcars dataset with ggplot
ggplot(mtcars, aes(x = wt, y = mpg)) +
    geom_point(size = 21, color = "red")
# Out:
# plot without title
# plot without title

# %%
# plot the mtcars dataset with ggplot
ggplot(mtcars, aes(x = wt, y = mpg)) +
    geom_point(size = 21, color = "red", alpha = 0.5)

# %%
# function for creating a scatter plot of the dataset
